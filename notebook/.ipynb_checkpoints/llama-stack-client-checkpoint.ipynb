# %%
import asyncio
import os

from llama_stack_client import LlamaStackClient
from llama_stack_client.lib.agents.agent import Agent
from llama_stack_client.lib.agents.event_logger import EventLogger
from rich.pretty import pprint

from dotenv import load_dotenv

load_dotenv()
BRAVE_SEARCH_API_KEY = os.environ["BRAVE_SEARCH_API_KEY"]
HOST=os.environ["HOST"]
PORT=os.environ["LLAMA_STACK_PORT"]
MODEL_NAME=os.environ["INFERENCE_MODEL"]
TAVILY_SEARCH_API_KEY=os.environ["TAVILY_API_KEY"]


#async def agent_example():
def agent_example():
    client = LlamaStackClient(base_url=f"http://{HOST}:{PORT}")
    agent = Agent(
        client, 
        model=MODEL_NAME,
        instructions="You are a helpful assistant! If you call builtin tools like brave search, follow the syntax brave_search.call(…)",
        #sampling_params={
        #"strategy": {"type": "greedy",},
        #},

        sampling_params={
        "strategy": {"type": "top_p", "temperature": 0.7, "top_p": 0.95},
        "max_tokens": 2048,
        },
        # there is problem with this format.
        # there are probably missing fields here.
        # we get an error - from the llama stack server POST return:
        # llama_stack_client.BadRequestError: Error code: 400 - 
        # {'error': 
        #  {'detail': 
        #   {'errors': 
        #    [{'loc': ['body', 'agent_config', 'toolgroups', 0, 'str'], 
        #             'msg': 'Input should be a valid string', 'type': 'string_type'}, 
        #             {'loc': ['body', 'agent_config', 'toolgroups', 0, 'AgentToolGroupWithArgs', 'name'], 'msg': 'Field required', 'type': 'missing'}, 
        #             {'loc': ['body', 'agent_config', 'toolgroups', 0, 'AgentToolGroupWithArgs', 'args'], 'msg': 'Field required', 'type': 'missing'}]}}}
        #tools=[
        #     {
        #         "type": "brave_search",
        #         "engine": "brave",
        #         "api_key": BRAVE_SEARCH_API_KEY,
        #     }
        # ],
        tools=(
            [
                "builtin::websearch",
            ]
            if os.getenv("TAVILY_S_API_KEY")
            else []
        ),
    )
    all_tools = client.tools.list()
    print("------------------")
    print(all_tools)
    print("------------------")
    return agent

# %%
agent=agent_example()
session_id = agent.create_session("test-session")
print(f"Created session_id={session_id} for Agent({agent.agent_id})")

user_prompts = [
     "I am planning a trip to Switzerland, what are the top 3 places to visit?",
    #"What is so special about #1?",
]

#for prompt in user_prompts:
response = agent.create_turn(
    messages=[
        {
            "role": "user",
            "content": "I am planning a trip to Switzerland, what are the top 3 places to visit?",
        }
    ],
    session_id=session_id,
    stream=False
)

print(response)
print("------------------")
print(response.input_messages)  # The turn ID
print("------------------")
print(response.steps)  # The status of the turn
print("------------------")
print(response.output_message)  # List of messages, including the response
print("------------------")
#print(dir(response))  # Shows all attributes and methods
print("------------------")
#print(response.__dict__)  # Shows the internal dictionary
# Out:
# ------------------
# [Tool(description='Execute code', identifier='code_interpreter', parameters=[Parameter(description='The code to execute', name='code', parameter_type='string', required=True, default=None)], provider_id='code-interpreter', provider_resource_id='code_interpreter', tool_host='distribution', toolgroup_id='builtin::code_interpreter', type='tool', metadata=None), Tool(description='Insert documents into memory', identifier='insert_into_memory', parameters=[], provider_id='rag-runtime', provider_resource_id='insert_into_memory', tool_host='distribution', toolgroup_id='builtin::rag', type='tool', metadata=None), Tool(description='Search for information in a database.', identifier='knowledge_search', parameters=[Parameter(description='The query to search for. Can be a natural language sentence or keywords.', name='query', parameter_type='string', required=True, default=None)], provider_id='rag-runtime', provider_resource_id='knowledge_search', tool_host='distribution', toolgroup_id='builtin::rag', type='tool', metadata=None), Tool(description='Search the web for information', identifier='web_search', parameters=[Parameter(description='The query to search for', name='query', parameter_type='string', required=True, default=None)], provider_id='tavily-search', provider_resource_id='web_search', tool_host='distribution', toolgroup_id='builtin::websearch', type='tool', metadata=None), Tool(description='Query WolframAlpha for computational knowledge', identifier='wolfram_alpha', parameters=[Parameter(description='The query to compute', name='query', parameter_type='string', required=True, default=None)], provider_id='wolfram-alpha', provider_resource_id='wolfram_alpha', tool_host='distribution', toolgroup_id='builtin::wolfram_alpha', type='tool', metadata=None)]
# ------------------
# Created session_id=94b3ce38-3ddb-4747-b64f-6634740d69b5 for Agent(44c26529-3e5f-4338-9afa-1ac2ad485384)
# Turn(input_messages=[UserMessage(content='I am planning a trip to Switzerland, what are the top 3 places to visit?', role='user', context=None)], output_message=CompletionMessage(content='Switzerland is a wonderful destination!\n\nHere are three must-visit places in Switzerland:\n\n1. **Jungfraujoch**: Also known as the "Top of Europe", Jungfraujoch is a mountain peak with breathtaking views of the surrounding Alps and glaciers. You can take a train to the top, where you\'ll find the "Ice Palace" (a stunning ice sculpture) and enjoy the panoramic views from 3,454 meters above sea level.\n2. **Lake Geneva** (Lac Léman): Located in western Switzerland, Lake Geneva is a beautiful lake with picturesque towns like Montreux, Vevey, and Évian-les-Bains. Enjoy boat cruises, visit the Chillon Castle, or simply take in the stunning views of the surrounding mountains.\n3. **Zurich Old Town** (Altstadt): This charming historic center in Zurich is filled with colorful buildings, narrow streets, Bahnhofstrasse (one of the world\'s most famous shopping streets), and picturesque squares like Marktplatz. Visit the iconic Fraumünster Church, the Swiss National Museum, or take a stroll along the Limmat River.\n\nThese three destinations offer a great mix of natural beauty, culture, and history. Of course, there are many more amazing places to explore in Switzerland, but this is a great starting point for your trip!\n\nWould you like more recommendations or have any specific interests (e.g., outdoor activities, food, wine)?', role='assistant', stop_reason='end_of_turn', tool_calls=[]), session_id='94b3ce38-3ddb-4747-b64f-6634740d69b5', started_at=datetime.datetime(2025, 3, 21, 11, 5, 47, 696563, tzinfo=TzInfo(-07:00)), steps=[InferenceStep(api_model_response=CompletionMessage(content='Switzerland is a wonderful destination!\n\nHere are three must-visit places in Switzerland:\n\n1. **Jungfraujoch**: Also known as the "Top of Europe", Jungfraujoch is a mountain peak with breathtaking views of the surrounding Alps and glaciers. You can take a train to the top, where you\'ll find the "Ice Palace" (a stunning ice sculpture) and enjoy the panoramic views from 3,454 meters above sea level.\n2. **Lake Geneva** (Lac Léman): Located in western Switzerland, Lake Geneva is a beautiful lake with picturesque towns like Montreux, Vevey, and Évian-les-Bains. Enjoy boat cruises, visit the Chillon Castle, or simply take in the stunning views of the surrounding mountains.\n3. **Zurich Old Town** (Altstadt): This charming historic center in Zurich is filled with colorful buildings, narrow streets, Bahnhofstrasse (one of the world\'s most famous shopping streets), and picturesque squares like Marktplatz. Visit the iconic Fraumünster Church, the Swiss National Museum, or take a stroll along the Limmat River.\n\nThese three destinations offer a great mix of natural beauty, culture, and history. Of course, there are many more amazing places to explore in Switzerland, but this is a great starting point for your trip!\n\nWould you like more recommendations or have any specific interests (e.g., outdoor activities, food, wine)?', role='assistant', stop_reason='end_of_turn', tool_calls=[]), step_id='167cabf8-dc5c-4b04-8f1a-442d898f8043', step_type='inference', turn_id='9f017e8f-1313-4db0-b7bf-f0906678cba8', completed_at=datetime.datetime(2025, 3, 21, 11, 6, 35, 989869, tzinfo=TzInfo(-07:00)), started_at=datetime.datetime(2025, 3, 21, 11, 5, 47, 697105, tzinfo=TzInfo(-07:00)))], turn_id='9f017e8f-1313-4db0-b7bf-f0906678cba8', completed_at=datetime.datetime(2025, 3, 21, 11, 6, 36, 5849, tzinfo=TzInfo(-07:00)), output_attachments=[])
# ------------------
# [UserMessage(content='I am planning a trip to Switzerland, what are the top 3 places to visit?', role='user', context=None)]
# ------------------
# [InferenceStep(api_model_response=CompletionMessage(content='Switzerland is a wonderful destination!\n\nHere are three must-visit places in Switzerland:\n\n1. **Jungfraujoch**: Also known as the "Top of Europe", Jungfraujoch is a mountain peak with breathtaking views of the surrounding Alps and glaciers. You can take a train to the top, where you\'ll find the "Ice Palace" (a stunning ice sculpture) and enjoy the panoramic views from 3,454 meters above sea level.\n2. **Lake Geneva** (Lac Léman): Located in western Switzerland, Lake Geneva is a beautiful lake with picturesque towns like Montreux, Vevey, and Évian-les-Bains. Enjoy boat cruises, visit the Chillon Castle, or simply take in the stunning views of the surrounding mountains.\n3. **Zurich Old Town** (Altstadt): This charming historic center in Zurich is filled with colorful buildings, narrow streets, Bahnhofstrasse (one of the world\'s most famous shopping streets), and picturesque squares like Marktplatz. Visit the iconic Fraumünster Church, the Swiss National Museum, or take a stroll along the Limmat River.\n\nThese three destinations offer a great mix of natural beauty, culture, and history. Of course, there are many more amazing places to explore in Switzerland, but this is a great starting point for your trip!\n\nWould you like more recommendations or have any specific interests (e.g., outdoor activities, food, wine)?', role='assistant', stop_reason='end_of_turn', tool_calls=[]), step_id='167cabf8-dc5c-4b04-8f1a-442d898f8043', step_type='inference', turn_id='9f017e8f-1313-4db0-b7bf-f0906678cba8', completed_at=datetime.datetime(2025, 3, 21, 11, 6, 35, 989869, tzinfo=TzInfo(-07:00)), started_at=datetime.datetime(2025, 3, 21, 11, 5, 47, 697105, tzinfo=TzInfo(-07:00)))]
# ------------------
# CompletionMessage(content='Switzerland is a wonderful destination!\n\nHere are three must-visit places in Switzerland:\n\n1. **Jungfraujoch**: Also known as the "Top of Europe", Jungfraujoch is a mountain peak with breathtaking views of the surrounding Alps and glaciers. You can take a train to the top, where you\'ll find the "Ice Palace" (a stunning ice sculpture) and enjoy the panoramic views from 3,454 meters above sea level.\n2. **Lake Geneva** (Lac Léman): Located in western Switzerland, Lake Geneva is a beautiful lake with picturesque towns like Montreux, Vevey, and Évian-les-Bains. Enjoy boat cruises, visit the Chillon Castle, or simply take in the stunning views of the surrounding mountains.\n3. **Zurich Old Town** (Altstadt): This charming historic center in Zurich is filled with colorful buildings, narrow streets, Bahnhofstrasse (one of the world\'s most famous shopping streets), and picturesque squares like Marktplatz. Visit the iconic Fraumünster Church, the Swiss National Museum, or take a stroll along the Limmat River.\n\nThese three destinations offer a great mix of natural beauty, culture, and history. Of course, there are many more amazing places to explore in Switzerland, but this is a great starting point for your trip!\n\nWould you like more recommendations or have any specific interests (e.g., outdoor activities, food, wine)?', role='assistant', stop_reason='end_of_turn', tool_calls=[])
# ------------------
# ------------------

# %%
session_id = agent.create_session("test-session-1")
user_prompts = [
     "I am planning a trip to Switzerland, what are the top 3 places to visit?",
     "What is so special about that place?",
]

for prompt in user_prompts:
    response = agent.create_turn(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        session_id=session_id,
        stream=True
    )
    # Monitor each step of execution
    for log in EventLogger().log(response):
        log.print()
# Out:
# inference> 🇨🇭 You're in for a treat! Switzerland is a beautiful country with a rich history, stunning mountains, and delicious chocolate. Here are my top 3 recommendations for places to visit:
#
# 1. **Jungfraujoch - "Top of Europe"**: Take the Jungfrau Railway (one of the world's most scenic train routes) to the "Top of Europe," where you'll find breathtaking views of the Eiger, Mönch, and Jungfrau mountains. The cogwheel railway takes you up to 3,454 meters (11,332 feet), offering stunning vistas of glaciers, valleys, and the surrounding peaks.
# 2. **Lake Geneva (Lac Léman)**: Located on the border with France and Italy, Lake Geneva is a beautiful destination for boating, swimming, or simply taking in the scenic views. Visit the historic Old Town, visit the Chillon Castle, or stroll along the lake's picturesque promenade.
# 3. **Zurich Old Town (Altstadt)**: The charming old town of Zurich is filled with narrow cobblestone streets, quaint shops, and traditional Swiss architecture. Be sure to visit the Bahnhofstrasse (main shopping street), explore the Fraumünster Church, and enjoy a delicious fondue dinner at one of the local restaurants.
#
# These three destinations are just a starting point for your Swiss adventure. Depending on your interests, you may also want to consider visiting other popular spots like Interlaken, Bern, St. Moritz, or the picturesque villages of Grindelwald or Adelboden.
#
# What type of vacation are you looking for (e.g., outdoor activities, cultural experiences, food and wine)? I can provide more tailored recommendations!
# inference> **Jungfraujoch - "Top of Europe"** has several unique aspects that make it a must-visit destination:
#
# 1. **Breathtaking views**: The Jungfrau Railway takes you to the highest train station in Europe, offering stunning 360-degree views of the surrounding mountains and glaciers.
# 2. **Alpine scenery**: The region is home to some of the most iconic Swiss Alps peaks, including the Eiger, Mönch, and Jungfrau, which are part of the "Three Peaks" (Eiger, Mönch, Jungfrau).
# 3. **Unique train experience**: The cogwheel railway is a feat of engineering that uses a complex system of gears to haul the train up steep inclines at speeds of up to 360 km/h (224 mph). It's an engineering marvel and a thrilling experience.
# 4. **Glacier exploration**: At the top, you can walk on the "Ice Palace" or explore the glaciers, which offer breathtaking views and a glimpse into the region's unique geological history.
# 5. **Astronomical observatory**: The Jungfraujoch has a weather station with an astronomical observatory that offers panoramic views of the night sky, making it an ideal spot for stargazing.
#
# **Lake Geneva (Lac Léman)** is special because:
#
# 1. **Strategic location**: Situated between France and Italy, Lake Geneva offers stunning views of the surrounding Alps and the French and Italian Riviera.
# 2. **History and culture**: The lake has a rich history, with evidence of human habitation dating back to ancient times.
# 3. **Luxury and elegance**: Lake Geneva is famous for its beautiful villas, gardens, and promenades, making it an ideal spot for relaxation and luxury.
#
# **Zurich Old Town (Altstadt)** is unique because:
#
# 1. **Well-preserved medieval architecture**: The old town features many well-preserved buildings from the 13th to 19th centuries, offering a glimpse into Zurich's rich history.
# 2. **Cultural attractions**: Visit the Fraumünster Church, the Kunsthaus art museum, or explore the narrow streets and alleys filled with boutiques, galleries, and traditional restaurants.
# 3. **Vibrant atmosphere**: The old town is lively, with many festivals, markets, and events throughout the year.
#
# These destinations offer a mix of natural beauty, rich history, and cultural experiences that showcase the best of Switzerland!
